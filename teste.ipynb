# %%
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/113.0"
}

pagina_atual = [str("https://www.kabum.com.br/hardware/processadores?page_number={}&page_size=100&facet_filters=&sort=offer_price").format(i) for i in range(1, 9)]

product_link = []
product_name = []
product_price = []

for link in pagina_atual:
    req = requests.get(link, headers=headers)
    soup = BeautifulSoup(req.text, 'html.parser')
    products = soup.find_all(class_='productCard')

    for product in products:
        product_path = (product.find('a'))['href']
        product_link.append(f"https://www.kabum.com.br{product_path}")

        name = product.find(class_='nameCard')
        product_name.append(name.text.strip())

        price = product.find(class_='priceCard')
        price_text = price.text.strip()
        price_digits = re.sub(r'[^0-9]', '', price_text)

        if price_digits:
            product_price.append(float(price_digits) / 100)
        else:
            product_price.append(None)  # Adiciona None se não houver preço válido

# Criando DataFrame
df = pd.DataFrame({"Link": product_link, "Nome": product_name, "Preço": product_price})

# CSV
df
# Out:
#                                                   Link  \
# 0    https://www.kabum.com.br/produto/167948/proces...
# 1    https://www.kabum.com.br/produto/169602/proces...
# 2    https://www.kabum.com.br/produto/161605/proces...
# 3    https://www.kabum.com.br/produto/442578/proces...
# 4    https://www.kabum.com.br/produto/462365/proces...
# ..                                                 ...
# 787  https://www.kabum.com.br/produto/112996/proces...
# 788  https://www.kabum.com.br/produto/425201/proces...
# 789  https://www.kabum.com.br/produto/99683/process...
# 790  https://www.kabum.com.br/produto/90443/process...
# 791  https://www.kabum.com.br/produto/84399/process...
#
#                                                   Nome    Preço
# 0    Processador Intel Core I7 10700 10ª Geração, 2...  2146.56
# 1    Processador Intel Celeron G5905, 4MB, 3.5ghz, ...   319.00
# 2    Processador AMD Ryzen 5 3400G, 3.7GHz (4.2GHz ...  1530.31
# 3    Processador Intel 1151 Core I5 8600 3.1ghz, 9M...   870.48
# 4    Processador AMD Ryzen 5 5600x, Cache 35mb 3.7g...  2450.16
# ..                                                 ...      ...
# 787  Processador Intel Core i7-10700K, 3.8GHz (5.1G...      NaN
# 788  Processador, Intel Core I7, 7700 3.60Ghz, 8MB,...      NaN
# 789  Processador Intel Core i5-9400F Coffee Lake, 2...      NaN
# 790  Processador Intel Core i7-7740X Kaby Lake, 4.3...      NaN
# 791  Processador Intel Core i5-7400 Kaby Lake, 3Ghz...      NaN
#
# [792 rows x 3 columns]

# %%
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd

headers = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'pt-BR,pt;q=0.8,en-US;q=0.5,en;q=0.3',
    'Connection': 'keep-alive',
    'Host': 'www.kabum.com.br',
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/113.0"
}

# pagina_atual = [str("https://www.kabum.com.br/hardware/processadores?page_number={}&page_size=100&facet_filters=&sort=offer_price").format(i) for i in range(1, 9)]

pagina_atual = [str("https://www.kabum.com.br/hardware/placa-de-video-vga?page_number={}&page_size=100&facet_filters=&sort=offer_price").format(i) for i in range(1, 15)]

product_link = []
product_name = []
product_price = []

for link in pagina_atual:
    req = requests.get(link, headers=headers)
    soup = BeautifulSoup(req.text, 'html.parser')
    products = soup.find_all(class_='productCard')

    for product in products:
        product_path = (product.find('a'))['href']
        product_link.append(f"https://www.kabum.com.br{product_path}")

        name = product.find(class_='nameCard')
        product_name.append(name.text.strip())

        price = product.find(class_='priceCard')
        price_text = price.text.strip()
        price_digits = re.sub(r'[^0-9]', '', price_text)

        if price_digits:
            product_price.append(float(price_digits) / 100) # dividindo por 100 pra ajustar a representação em centavos
        else:
            product_price.append(None)  # Adiciona None se não houver preço válido

# Criando DataFrame
df = pd.DataFrame({"Link": product_link, "Nome": product_name, "Preço": product_price})

# CSV
df
# Out:
#                                                    Link  \
# 0     https://www.kabum.com.br/produto/171375/placa-...
# 1     https://www.kabum.com.br/produto/168189/placa-...
# 2     https://www.kabum.com.br/produto/171573/placa-...
# 3     https://www.kabum.com.br/produto/163822/placa-...
# 4     https://www.kabum.com.br/produto/207731/placa-...
# ...                                                 ...
# 1298  https://www.kabum.com.br/produto/171446/placa-...
# 1299  https://www.kabum.com.br/produto/189891/placa-...
# 1300  https://www.kabum.com.br/produto/271544/placa-...
# 1301  https://www.kabum.com.br/produto/315061/placa-...
# 1302  https://www.kabum.com.br/produto/341204/placa-...
#
#                                                    Nome    Preço
# 0     Placa de Vídeo Afox AMD Radeon R5 220, 2GB DDR...   299.99
# 1     Placa de Vídeo Palit NVIDIA GeForce GTX 1050 T...  1289.37
# 2     Placa de Vídeo PCYes NVIDIA GeForce GPU R5 230...   326.00
# 3     Placa de Vídeo PowerColor AMD Radeon RedDragon...  1227.08
# 4     Placa de Vídeo Colorful NVIDIA GeForce GTX 105...  1301.07
# ...                                                 ...      ...
# 1298  Placa de Vídeo Nvidia Duex GT730, 4GB DDR3, 12...      NaN
# 1299  Placa de Vídeo Duex NVIDIA GeForce GT 730, 2GB...      NaN
# 1300  Placa de Vídeo GTX 750 Ti Duex NVIDIA GeForce,...      NaN
# 1301  Placa de Vídeo PCYes NVIDIA GeForce GT730, 4GB...      NaN
# 1302  Placa de Ví­deo MSI NVIDIA GeForce RTX 2060, 6...      NaN
#
# [1303 rows x 3 columns]
